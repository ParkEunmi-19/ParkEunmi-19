# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkEunmi-19/ParkEunmi-19/blob/STUDY/data_reload_activate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import glob
import time
import argparse
import tqdm
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
import sys

from PIL import Image
from sklearn.model_selection import train_test_split
#from logging import get_tqdm_config
#from logging import get_gqdm_config
import logging

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
 
# for reproducibility
torch.manual_seed(777)
if device == 'cuda':
    torch.cuda.manual_seed_all(777)
 
print(device)

# %%
print(sys.path)

# %%
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %%
print(sys.path)

# %%
# !data_reload.py

# %%
# !ls

# %%
os.chdir('drive/My Drive/Colab Notebooks')

# %%
# !ls

# %%
# !python colab_data_reload.py
